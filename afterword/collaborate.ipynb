# %% [markdown]
# # Collaborate With Us
#
# Do you have ideas how to improve these notes? Submit your ideas below and we will get back to you 😊

# %%
from IPython.display import HTML
HTML(
"""
<iframe
    src="https://melbourneuni.au1.qualtrics.com/jfe/form/SV_9ADl5kW9Ov48Guq"
    width="640"
    height="919"
    frameborder="0"
    marginheight="0"
    marginwidth="0">
    Loading…
</iframe>
"""
)
# Out:
# <iframe
#     src="https://melbourneuni.au1.qualtrics.com/jfe/form/SV_9ADl5kW9Ov48Guq"
#     width="640"
#     height="919"
#     frameborder="0"
#     marginheight="0"
#     marginwidth="0">
#     Loading…
# </iframe>
